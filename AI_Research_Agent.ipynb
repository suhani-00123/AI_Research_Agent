# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
from google.colab import userdata

# %% [markdown]
# **Load the API Key**
#
# The API key is loaded securely from Colab Secrets instead of writing it directly in the notebook.

# %%
API_KEY = userdata.get("GROQ_API_KEY")

# %%
genai.configure(api_key=API_KEY)

# %% [markdown]
# **Initialize the Model**
#
# The model is responsible for understanding prompts and generating responses.

# %%
model = genai.GenerativeModel("gemini-3.5-flash")

# %% [markdown]
# **Test the Connection**
#
# Before building the project, verify that the model is responding correctly.

# %%
response = model.generate_content("Hello")

print(response.text)
# Out:
# Hello! How can I help you today?

# %% [markdown]
# **Create a Reusable Function**
#
# Using a function avoids repeating the same code every time a prompt is sent.

# %%
def ask_ai(question):

    response = model.generate_content(question)

    return response.text

# %%
question = input("Ask Your Question: ")

answer = ask_ai(question)

print(answer)
# Out:
# Ask Your Question: what is ai?
# At its simplest, **Artificial Intelligence (AI)** is the subfield of computer science dedicated to creating software and hardware that can "think," learn, and make decisions like a human.
#
# Instead of just following rigid, pre-programmed instructions (like a traditional calculator), AI systems analyze massive amounts of data, recognize patterns, and adapt to new inputs to solve complex problems.
#
# Here is a breakdown of how AI works, its different types, and how it is used today.
#
# ---
#
# ### 1. How Does AI Work?
# Modern AI relies on a few key concepts:
#
# *   **Data:** AI needs "fuel" to learn. This fuel is data (text, images, numbers, or videos).
# *   **Algorithms:** These are sets of rules or instructions given to a computer.
# *   **Machine Learning (ML):** This is the most common form of AI today. Instead of programming a computer with exact rules, you feed it data and let the computer figure out the rules itself. For example, by showing a computer millions of pictures of cats, it learns to recognize a cat on its own.
# *   **Deep Learning:** A subset of Machine Learning inspired by the human brain. It uses "neural networks" (layer upon layer of algorithms) to process information in a highly complex way. This is what powers self-driving cars and facial recognition.
#
# ---
#
# ### 2. The Two Main Types of AI
#
# Scientists generally divide AI into two categories:
#
# #### A. Narrow AI (Weak AI)
# This is the AI we have **today**. It is highly specialized and designed to perform a single, specific task exceptionally well.
# *   *Examples:* Apple's Siri, Google Maps, chess-playing computers, and Netflix recommendation algorithms. Siri can tell you the weather, but it cannot paint a picture or write a legal contract from scratch.
#
# #### B. General AI (Strong AI or AGI)
# This is **hypothetical** AI. It refers to a machine that has human-level intelligence across all domains. It could learn, reason, adapt, and solve problems in the same way a human can. True AGI does not exist yet, though companies like OpenAI and Google are actively trying to build it.
#
# ---
#
# ### 3. Common Examples of AI in Daily Life
# You likely interact with AI dozens of times a day without realizing it:
#
# *   **Generative AI:** Tools like ChatGPT, Claude, and Midjourney that can write essays, write code, and create stunning artwork from simple text prompts.
# *   **Search Engines:** Google uses AI to understand the *intent* behind your search, rather than just matching exact words.
# *   **Social Media:** Algorithms on TikTok, Instagram, and YouTube analyze your behavior to show you videos you are most likely to watch.
# *   **Streaming & Shopping:** Netflix and Amazon use AI to recommend movies and products based on your past history.
# *   **Smart Assistants:** Siri, Alexa, and Google Assistant use Natural Language Processing (NLP) to understand your voice.
# *   **Navigation:** Waze and Google Maps use AI to predict traffic and calculate the fastest route in real-time.
#
# ---
#
# ### 4. Why is AI so important right now?
# AI is undergoing a massive boom because of three factors: **unprecedented computing power**, the **explosion of digital data**, and **breakthroughs in algorithms** (like the "Transformer" model that powers ChatGPT).
#
# AI is poised to revolutionize major industries:
# *   **Medicine:** AI can analyze X-rays to detect cancer faster than human doctors and design new life-saving drugs in days rather than years.
# *   **Climate Change:** AI is used to optimize energy grids, track deforestation, and predict extreme weather patterns.
# *   **Finance:** AI detects fraudulent credit card transactions in milliseconds.
#
# ---
#
# ### 5. Challenges and Risks of AI
# While AI has incredible potential, it also presents significant challenges:
# *   **Bias:** AI learns from human data. If the data contains biases (racism, sexism, etc.), the AI will replicate and amplify those biases.
# *   **Job Displacement:** AI will automate many tasks, potentially displacing workers in fields like customer service, writing, coding, and administrative work.
# *   **Misinformation:** "Deepfakes" (AI-generated fake videos and audio) and AI-written fake news make it difficult to trust what we see and hear online.
# *   **Safety & Control:** As AI becomes more powerful, ensuring it aligns with human values and doesn't behave in unintended, harmful ways is a major field of research.

# %%
# !pip install -q tavily-python

# %%
from tavily import TavilyClient

# %% [markdown]
# **Load Tavily API Key**
#
# The Tavily API key is loaded securely from Colab Secrets.

# %%
TAVILY_API_KEY = userdata.get("TAVILY_API_KEY")

# %%
tavily = TavilyClient(api_key=TAVILY_API_KEY)

# %% [markdown]
# **Create Search Function**
#
# This function searches the web and returns the latest results.

# %%
def search_web(query):

    result = tavily.search(
        query=query,
        max_results=3
    )

    return result

# %%
result = search_web("Latest AI News")

print(result)
# Out:
# {'query': 'Latest AI News', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.artificialintelligence-news.com', 'title': 'AI News | Latest News | Insights Powering AI-Driven Business ...', 'content': '[![Image 1](https://www.artificialintelligence-news.com/wp-content/uploads/2025/01/AI-News-White-1.png)](https://www.artificialintelligence-news.com/). *   [Categories](https://www.artificialintelligence-news.com/#). *   [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). *   [World of Work](https://www.artificialintelligence-news.com/categories/ai-and-us/world-of-work/). *   [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). *   [Marketing AI](https://www.artificialintelligence-news.com/categories/ai-in-action/marketing-ai/). *   [Utilities](https://www.artificialintelligence-news.com/categories/ai-in-action/utilities/). *   [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). *   [Categories](https://www.artificialintelligence-news.com/#). *   [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). *   [World of Work](https://www.artificialintelligence-news.com/categories/ai-and-us/world-of-work/). *   [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). *   [Marketing AI](https://www.artificialintelligence-news.com/categories/ai-in-action/marketing-ai/). *   [Utilities](https://www.artificialintelligence-news.com/categories/ai-in-action/utilities/). *   [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). [![Image 2](https://www.artificialintelligence-news.com/wp-content/uploads/2025/01/AI-News-White-1.png)](https://www.artificialintelligence-news.com/). *   [Categories](https://www.artificialintelligence-news.com/#). *   [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). *   [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). *   [Marketing AI](https://www.artificialintelligence-news.com/categories/ai-in-action/marketing-ai/). *   [Utilities](https://www.artificialintelligence-news.com/categories/ai-in-action/utilities/). *   [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [Explore More](https://www.artificialintelligence-news.com/categories/ai-in-action/finance-ai/). #### [Applications](https://www.artificialintelligence-news.com/categories/ai-applications/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [Marketing AI](https://www.artificialintelligence-news.com/categories/ai-in-action/marketing-ai/). [![Image 25](https://www.artificialintelligence-news.com/wp-content/uploads/2026/06/AI-Europe-300x600-1.png)](https://www.ai-expo.net/europe). #### [Enterprise](https://www.artificialintelligence-news.com/categories/ai-enterprise/). [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). #### [Industries](https://www.artificialintelligence-news.com/categories/ai-industries/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [AI in Action](https://www.artificialintelligence-news.com/categories/a ...

# %% [markdown]
# **Display Search Results**
#
# Extract only the useful information from the search response.

# %%
for item in result["results"]:

    print("=" * 60)

    print("Title :", item["title"])

    print("URL :", item["url"])

    print()

    print(item["content"])

    print()
# Out:
# ============================================================
# Title : AI News | Latest News | Insights Powering AI-Driven Business ...
# URL : https://www.artificialintelligence-news.com
#
# [![Image 1](https://www.artificialintelligence-news.com/wp-content/uploads/2025/01/AI-News-White-1.png)](https://www.artificialintelligence-news.com/). *   [Categories](https://www.artificialintelligence-news.com/#). *   [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). *   [World of Work](https://www.artificialintelligence-news.com/categories/ai-and-us/world-of-work/). *   [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). *   [Marketing AI](https://www.artificialintelligence-news.com/categories/ai-in-action/marketing-ai/). *   [Utilities](https://www.artificialintelligence-news.com/categories/ai-in-action/utilities/). *   [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). *   [Categories](https://www.artificialintelligence-news.com/#). *   [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). *   [World of Work](https://www.artificialintelligence-news.com/categories/ai-and-us/world-of-work/). *   [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). *   [Marketing AI](https://www.artificialintelligence-news.com/categories/ai-in-action/marketing-ai/). *   [Utilities](https://www.artificialintelligence-news.com/categories/ai-in-action/utilities/). *   [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). [![Image 2](https://www.artificialintelligence-news.com/wp-content/uploads/2025/01/AI-News-White-1.png)](https://www.artificialintelligence-news.com/). *   [Categories](https://www.artificialintelligence-news.com/#). *   [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). *   [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). *   [Marketing AI](https://www.artificialintelligence-news.com/categories/ai-in-action/marketing-ai/). *   [Utilities](https://www.artificialintelligence-news.com/categories/ai-in-action/utilities/). *   [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [Explore More](https://www.artificialintelligence-news.com/categories/ai-in-action/finance-ai/). #### [Applications](https://www.artificialintelligence-news.com/categories/ai-applications/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [Marketing AI](https://www.artificialintelligence-news.com/categories/ai-in-action/marketing-ai/). [![Image 25](https://www.artificialintelligence-news.com/wp-content/uploads/2026/06/AI-Europe-300x600-1.png)](https://www.ai-expo.net/europe). #### [Enterprise](https://www.artificialintelligence-news.com/categories/ai-enterprise/). [Inside AI](https://www.artificialintelligence-news.com/categories/inside-ai/). #### [Industries](https://www.artificialintelligence-news.com/categories/ai-industries/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [AI in Action](https://www.artificialintelligence-news.com/categories/ai-in-action/). [AI and Us](https://www.artificialintelligence-news.com/categories/ai-and-us/). [![Image 27](https://www.artificialintelligence-news.com/wp-content/uploads/2026/01/EXL-July-2025-2-1024x512.png)](https://www.artificialintelligenc ...
#
# ============================================================
# Title : Artificial Intelligence - Latest AI News and Analysis
# URL : https://www.wsj.com/tech/ai
#
# Plus, a plan to protect Earth from solar storms, how to shop for iPhones this year, how AI advice is undermining eating-disorder therapy and more. The resistance to artificial intelligence is growing—although one activist’s disappearance has the movement on edge. Image thumbnail for article titled The Economics of Friendship. Image thumbnail for article titled Is Private AI Regulation Constitutional? Image thumbnail for article titled Will Washington State Choose Stagnation Over Growth? Image thumbnail for article titled A Christian Vision for the Future of AI. ### A Christian Vision for the Future of AI. Image thumbnail for article titled The Heart Beats the Machine. Shares of MiniMax dropped after the Chinese artificial-intelligence company disclosed a plan to raise $2 billion through a share placement and convertible-bond offering. Shares of the Chinese artificial-intelligence company rose sharply after it announced plans for a US$4 billion fundraising to support growth, despite pricing the new shares at a discount.
#
# ============================================================
# Title : Artificial Intelligence - Latest AI News - Reuters
# URL : https://www.reuters.com/technology/artificial-intelligence
#
# *   [World](https://www.reuters.com/world/). ## [Browse World](https://www.reuters.com/world/). *   [Africa](https://www.reuters.com/world/africa/). *   [Americas](https://www.reuters.com/world/americas/). *   [China](https://www.reuters.com/world/china/). *   [Europe](https://www.reuters.com/world/europe/). *   [India](https://www.reuters.com/world/india/). *   [Japan](https://www.reuters.com/world/japan/). *   [United Kingdom](https://www.reuters.com/world/uk/). *   [United States](https://www.reuters.com/world/us/). *   [Reuters NEXT](https://www.reuters.com/world/reuters-next/). *   [Business](https://www.reuters.com/business/). ## [Browse Business](https://www.reuters.com/business/). *   [Take Five](https://www.reuters.com/business/take-five/). *   [Markets](https://www.reuters.com/markets/). ## [Browse Markets](https://www.reuters.com/markets/). *   [Sustainability](https://www.reuters.com/sustainability/). ## [Browse Sustainability](https://www.reuters.com/sustainability/). *   [Legal](https://www.reuters.com/legal/). ## [Browse Legal](https://www.reuters.com/legal/). ## [Commentary](https://www.reuters.com/commentary/). ## [Technology](https://www.reuters.com/technology/). *   [Artificial Intelligence](https://www.reuters.com/technology/artificial-intelligence/). *   [Cybersecurity](https://www.reuters.com/technology/cybersecurity/). *   [Space](https://www.reuters.com/technology/space/). *   [Disrupted](https://www.reuters.com/technology/disrupted/). ## [Investigations](https://www.reuters.com/investigations/). ## [Sports](https://www.reuters.com/sports/). ## [Science](https://www.reuters.com/science/). ## [Lifestyle](https://www.reuters.com/lifestyle/). ## [Graphics](https://www.reuters.com/graphics/). ## [Podcasts](https://www.reuters.com/podcasts/). ## [Live](https://www.reuters.com/live/). ## [Video](https://www.reuters.com/video/). *   [Artificial Intelligence](https://www.reuters.com/technology/artificial-intelligence/). *   [Cybersecurity](https://www.reuters.com/technology/cybersecurity/). *   [Space](https://www.reuters.com/technology/space/). *   [Disrupted](https://www.reuters.com/technology/disrupted/). [Video 1](https://www.reuters.com/technology/artificial-intelligence). [Video 2](https://www.reuters.com/technology/artificial-intelligence). [Video 3](https://www.reuters.com/technology/artificial-intelligence). [Video 4](https://www.reuters.com/technology/artificial-intelligence). *   [China to let AI firms buy Nvidia H200 chips, the Information reports](https://www.reuters.com/technology/artificial-intelligence#) [](https://www.reuters.com/technology/artificial-intelligence#). [See all videos](https://www.reuters.com/video/technology/). *   [Home](https://www.reuters.com/). *   [Archive](https://www.reuters.com/archive/). *    [Videos](https://www.reuters.com/video/). *    [Graphics](https://www.reuters.com/graphics/). *    [Podcasts](https://www.reuters.com/podcasts/). *   [Home](https://www.reuters.com/). *   [Archive](https://www.reuters.com/archive/). *   [World](https://www.reuters.com/world/). *   [Business](https://www.reuters.com/business/). *   [Markets](https://www.reuters.com/markets/). *   [Sustainability](https://www.reuters.com/sustainability/). *   [Legal](https://www.reuters.com/legal/). *   [Breakingviews](https://www.reuters.com/breakingviews/). *   [Technology](https://www.reuters.com/technology/). *   [Investigations](https://www.reuters.com/investigations/). *   [Sports](https://www.reuters.com/sports/). *   [Science](https://www.reuters.com/science/). *   [Lifestyle](https://www.reuters.com/lifestyle/). *    [Videos](https://www.reuters.com/video/). *    [Graphics](https://www.reuters.com/graphics/). *    [Podcasts](https://www.reuters.com/podcasts/). *   [Newsletters](https://www.reuters.com/newsletters/). *   [](https://www.facebook.com/Reuters). *   [](https://www.instagram.com/Reuters).

# %% [markdown]
# The model decides if the question requires a web search.

# %%
def should_search(question):

    prompt = f"""
You are an AI Research Assistant.

Decide whether the following question needs a web search.

Reply with only one word:

YES
or
NO

Question:
{question}
"""

    response = ask_ai(prompt)

    return response.strip().upper()

# %%
question = input("Ask Your Question: ")

decision = should_search(question)

print("Decision :", decision)
# Out:
# Ask Your Question: what is python?
# Decision : NO

# %% [markdown]
# **Generate Final Answer**
#
# If a web search is required, use the search results to generate a better response.

# %%
def research(question):

    decision = should_search(question)

    if "YES" in decision:

        result = search_web(question)

        context = ""

        for item in result["results"]:
            context += item["content"] + "\n"

        prompt = f"""
Question:
{question}

Search Results:
{context}

Using the search results, write a clear and detailed answer.
"""

        return ask_ai(prompt)

    else:

        return ask_ai(question)

# %%
question = input("Ask Your Question: ")

answer = research(question)

print("\nAnswer:\n")

print(answer)
# Out:
# Ask Your Question: ai latest news
# ERROR:tornado.access:503 POST /v1beta/models/gemini-3.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2170.81ms
# Answer:
#
# Based on the latest developments from June and July 2026, here is a detailed breakdown of the most significant news and updates in the field of Artificial Intelligence:
#
# ---
#
# ### **1. Major AI Model Releases & Corporate Updates**
# *   **Anthropic’s Claude Fable & Mythos 5:** Anthropic released its new models, *Claude Fable* and *Mythos 5*. However, the release was met with backlash and scrutiny following reports of a "silent downgrade" of Fable 5, raising transparency and national security concerns.
# *   **Apple’s Generative AI Push:** Apple officially introduced its next-generation **Apple Intelligence** alongside a profoundly upgraded **Siri AI**. The update aims to integrate powerful, highly personal generative AI capabilities directly into everyday iOS and macOS experiences.
# *   **Google’s AI Improvements:**
#     *   **Gemini Live 3.5 Translate:** Google introduced an upgraded real-time translation feature.
#     *   **DiffusionGemma:** A new release aimed at accelerating text generation speeds for developers.
#     *   **NotebookLM:** Google rolled out updates to its research assistant tool to streamline information synthesis.
#
# ---
#
# ### **2. OpenAI's Financial and Feature Milestones**
# *   **Confidential S-1 Filing:** In a major financial move, OpenAI has submitted a confidential S-1 filing, indicating that the company is actively preparing for an Initial Public Offering (IPO).
# *   **ChatGPT Email Integration:** ChatGPT added capability improvements, notably enabling the system to draft and send emails directly.
# *   **Industry Manifestos:** Both OpenAI’s Sam Altman ("Built to Benefit Everyone: Our Plan") and Anthropic's Dario Amodei ("Policy on the AI Exponential") published new manifestos addressing safety, policy, and the long-term societal impacts of exponential AI growth.
#
# ---
#
# ### **3. AI Infrastructure, Hardware, & Agent Economy**
# *   **Coinbase for Agents:** Facilitating the economy of autonomous AI, Coinbase launched "Coinbase for Agents," a platform designed to let AI agents conduct financial transactions.
# *   **Midjourney Hardware:** Midjourney has officially announced its expansion into physical technology with a new hardware launch.
# *   **Nokia Supplies Data Center Boom:** Nokia has emerged as a key supplier feeding the surging demand for physical infrastructure, providing critical networking hardware to fuel the AI data center boom.
#
# ---
#
# ### **4. Real-World Industry Adoption & Debates**
# *   **State Farm’s AI Overhaul:** State Farm launched a massive, controversial "AI Makeover" aimed at leapfrogging its traditional insurance business model into the 21st century. The move has sparked heated debate, drawing feedback from over 1,000 customers and industry watchers regarding automated decision-making in insurance.
# *   **AI in Medicine:** Despite rapid technological advances, medical and ethics experts continue to highlight limitations. Recent discussions in healthcare emphasize "the crucial medical question that AI can't ever answer," reminding the industry that human empathy and nuanced clinical judgment remain irreplaceable.

# %% [markdown]
# **Save the Research Report**
#
# Save the generated answer in a text file.

# %%
if "YES" in should_search(question):

    print("\nSources:\n")

    result = search_web(question)

    for item in result["results"]:
        print(item["url"])
# Out:
# Sources:
#
# https://www.artificialintelligence-news.com
# https://www.youtube.com/watch?v=nydHKXjwu0U
# https://guides.library.georgetown.edu/ai/news

# %%
from datetime import datetime

# %%
file_name = f"Research_Report_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"

# %%
with open(file_name, "w", encoding="utf-8") as file:
    file.write(answer)

print(f"Report saved as {file_name}")
# Out:
# Report saved as Research_Report_20260714_110439.txt

# %%
with open(file_name, "r", encoding="utf-8") as file:
    print(file.read())
# Out:
# Based on the latest developments from June and July 2026, here is a detailed breakdown of the most significant news and updates in the field of Artificial Intelligence:
#
# ---
#
# ### **1. Major AI Model Releases & Corporate Updates**
# *   **Anthropic’s Claude Fable & Mythos 5:** Anthropic released its new models, *Claude Fable* and *Mythos 5*. However, the release was met with backlash and scrutiny following reports of a "silent downgrade" of Fable 5, raising transparency and national security concerns.
# *   **Apple’s Generative AI Push:** Apple officially introduced its next-generation **Apple Intelligence** alongside a profoundly upgraded **Siri AI**. The update aims to integrate powerful, highly personal generative AI capabilities directly into everyday iOS and macOS experiences.
# *   **Google’s AI Improvements:**
#     *   **Gemini Live 3.5 Translate:** Google introduced an upgraded real-time translation feature.
#     *   **DiffusionGemma:** A new release aimed at accelerating text generation speeds for developers.
#     *   **NotebookLM:** Google rolled out updates to its research assistant tool to streamline information synthesis.
#
# ---
#
# ### **2. OpenAI's Financial and Feature Milestones**
# *   **Confidential S-1 Filing:** In a major financial move, OpenAI has submitted a confidential S-1 filing, indicating that the company is actively preparing for an Initial Public Offering (IPO).
# *   **ChatGPT Email Integration:** ChatGPT added capability improvements, notably enabling the system to draft and send emails directly.
# *   **Industry Manifestos:** Both OpenAI’s Sam Altman ("Built to Benefit Everyone: Our Plan") and Anthropic's Dario Amodei ("Policy on the AI Exponential") published new manifestos addressing safety, policy, and the long-term societal impacts of exponential AI growth.
#
# ---
#
# ### **3. AI Infrastructure, Hardware, & Agent Economy**
# *   **Coinbase for Agents:** Facilitating the economy of autonomous AI, Coinbase launched "Coinbase for Agents," a platform designed to let AI agents conduct financial transactions.
# *   **Midjourney Hardware:** Midjourney has officially announced its expansion into physical technology with a new hardware launch.
# *   **Nokia Supplies Data Center Boom:** Nokia has emerged as a key supplier feeding the surging demand for physical infrastructure, providing critical networking hardware to fuel the AI data center boom.
#
# ---
#
# ### **4. Real-World Industry Adoption & Debates**
# *   **State Farm’s AI Overhaul:** State Farm launched a massive, controversial "AI Makeover" aimed at leapfrogging its traditional insurance business model into the 21st century. The move has sparked heated debate, drawing feedback from over 1,000 customers and industry watchers regarding automated decision-making in insurance.
# *   **AI in Medicine:** Despite rapid technological advances, medical and ethics experts continue to highlight limitations. Recent discussions in healthcare emphasize "the crucial medical question that AI can't ever answer," reminding the industry that human empathy and nuanced clinical judgment remain irreplaceable.

# %% [markdown]
# **Create Chat History**

# %%
chat_history = []

# %%
question = input("Ask Your Question: ")

answer = research(question)

chat_history.append({
    "Question": question,
    "Answer": answer
})

print("\nAnswer:\n")
print(answer)
# Out:
# Ask Your Question: ai project
#
# Answer:
#
# Based on the provided search results, here is a detailed breakdown of what an AI project is, how it is used in scientific research, and practical project ideas for students.
#
# ---
#
# ### 1. What is an AI Project?
# At its core, an AI project is an effort to solve a specific problem using **data** rather than fixed rules.
# * **Traditional Software vs. AI:** In traditional software, you write explicit instructions (e.g., *"If the user clicks this, do that"*). In an AI project, you provide the computer with thousands of examples and let it learn on its own (e.g., showing a model 10,000 photos of cats and dogs so it learns to tell them apart).
# * **The Importance of Data:** AI projects rely heavily on the quality of their training data, following the famous saying: **“Garbage In, Garbage Out.”** If an AI trained to recognize healthy plants is only shown pictures of indoor plants, it will fail to recognize healthy outdoor trees. For an AI project to succeed, its training data must be diverse and accurate.
# * **Deployment:** Once trained, the AI enters the deployment phase of its life cycle, where it is integrated into a real-world application or website for people to use. Anyone can start an AI project; you do not need to be a scientist.
#
# ---
#
# ### 2. Scientific AI Projects
# Artificial intelligence is being used in advanced scientific research to accelerate discoveries and solve complex physical problems. Real-world examples of scientific AI projects include:
# * **Solving the Quantum Many-Body Problem:** Using artificial neural networks to develop materials for solar energy, next-generation chemical catalysis, and battery technology.
# * **Battery Performance Diagnosis:** Utilizing AI to diagnose and predict battery health and performance, accelerating the deployment of new energy storage systems.
# * **AuroraGPT:** Creating foundation models specifically designed for scientific applications.
# * **Gravitational Wave Astrophysics:** Combining High-Performance Computing (HPC) and AI to analyze astrophysics data.
# * **AI Accelerator Testing:** Assessing how effectively new AI accelerator systems handle scientific machine learning applications.
#
# ---
#
# ### 3. Student AI Project Ideas
# For students, building hands-on AI projects is a way to practice Python, machine learning, deep learning, Natural Language Processing (NLP), computer vision, and Generative AI (GenAI) while building a portfolio for GitHub.
#
# Project ideas range from beginner to advanced levels:
# * **Beginner to Intermediate Projects:**
#   * **Email Spam Detection** (identifying unwanted emails).
#   * **Sentiment Analysis** (evaluating the tone or emotion of text).
#   * **House Price Prediction** (forecasting real estate prices based on data).
# * **Advanced Projects:**
#   * **Object Detection** (identifying and labeling items within images).
#   * **Resume Parsing** (extracting structured information from CVs).
#   * **Text Summarization** (condensing long texts into shorter summaries).
#   * **RAG-based Q&A Systems** (Retrieval-Augmented Generation systems to answer questions based on specific documents).
#   * **AI Agents** (autonomous systems designed to achieve specific goals).
#   * **LLM Fine-Tuning** (customizing large language models for specific tasks).

# %% [markdown]
# **View Chat History**

# %%
for chat in chat_history:

    print("=" * 60)

    print("Question:")
    print(chat["Question"])

    print()

    print("Answer:")
    print(chat["Answer"])

    print()
# Out:
# ============================================================
# Question:
# ai project
#
# Answer:
# Based on the provided search results, here is a detailed breakdown of what an AI project is, how it is used in scientific research, and practical project ideas for students.
#
# ---
#
# ### 1. What is an AI Project?
# At its core, an AI project is an effort to solve a specific problem using **data** rather than fixed rules.
# * **Traditional Software vs. AI:** In traditional software, you write explicit instructions (e.g., *"If the user clicks this, do that"*). In an AI project, you provide the computer with thousands of examples and let it learn on its own (e.g., showing a model 10,000 photos of cats and dogs so it learns to tell them apart).
# * **The Importance of Data:** AI projects rely heavily on the quality of their training data, following the famous saying: **“Garbage In, Garbage Out.”** If an AI trained to recognize healthy plants is only shown pictures of indoor plants, it will fail to recognize healthy outdoor trees. For an AI project to succeed, its training data must be diverse and accurate.
# * **Deployment:** Once trained, the AI enters the deployment phase of its life cycle, where it is integrated into a real-world application or website for people to use. Anyone can start an AI project; you do not need to be a scientist.
#
# ---
#
# ### 2. Scientific AI Projects
# Artificial intelligence is being used in advanced scientific research to accelerate discoveries and solve complex physical problems. Real-world examples of scientific AI projects include:
# * **Solving the Quantum Many-Body Problem:** Using artificial neural networks to develop materials for solar energy, next-generation chemical catalysis, and battery technology.
# * **Battery Performance Diagnosis:** Utilizing AI to diagnose and predict battery health and performance, accelerating the deployment of new energy storage systems.
# * **AuroraGPT:** Creating foundation models specifically designed for scientific applications.
# * **Gravitational Wave Astrophysics:** Combining High-Performance Computing (HPC) and AI to analyze astrophysics data.
# * **AI Accelerator Testing:** Assessing how effectively new AI accelerator systems handle scientific machine learning applications.
#
# ---
#
# ### 3. Student AI Project Ideas
# For students, building hands-on AI projects is a way to practice Python, machine learning, deep learning, Natural Language Processing (NLP), computer vision, and Generative AI (GenAI) while building a portfolio for GitHub.
#
# Project ideas range from beginner to advanced levels:
# * **Beginner to Intermediate Projects:**
#   * **Email Spam Detection** (identifying unwanted emails).
#   * **Sentiment Analysis** (evaluating the tone or emotion of text).
#   * **House Price Prediction** (forecasting real estate prices based on data).
# * **Advanced Projects:**
#   * **Object Detection** (identifying and labeling items within images).
#   * **Resume Parsing** (extracting structured information from CVs).
#   * **Text Summarization** (condensing long texts into shorter summaries).
#   * **RAG-based Q&A Systems** (Retrieval-Augmented Generation systems to answer questions based on specific documents).
#   * **AI Agents** (autonomous systems designed to achieve specific goals).
#   * **LLM Fine-Tuning** (customizing large language models for specific tasks).

# %%
with open("chat_history.txt", "w", encoding="utf-8") as file:

    for chat in chat_history:

        file.write(f"Question: {chat['Question']}\n")

        file.write(f"Answer: {chat['Answer']}\n")

        file.write("-" * 60 + "\n")

print("Chat history saved successfully.")
# Out:
# Chat history saved successfully.
